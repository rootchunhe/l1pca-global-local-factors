# %%
import sys; sys.path.insert(0, ".")
from port_sort import get_beta_shock_panel, plot_beta_shock_monthly_groups, plot_beta_shock_event_decay

# %%
# Build beta-shock panel
k_group = 10
panel = get_beta_shock_panel()

# %%
# Monthly beta shock groups (EW)
ts_ew = plot_beta_shock_monthly_groups(panel, k_group=k_group, value_weighted=False)

# %%
# Monthly beta shock groups (VW)
ts_vw = plot_beta_shock_monthly_groups(panel, k_group=k_group, value_weighted=True)

# %%
# Event-time decay (EW)
decay_ew = plot_beta_shock_event_decay(panel, k_group=k_group, value_weighted=False)

# %%
# Event-time decay (VW)
decay_vw = plot_beta_shock_event_decay(panel, k_group=k_group, value_weighted=True)
