# %%
from cases import run_case_study

# %%
summary, df = run_case_study("oil_shock") # "svb", "deepseek", "oil_shock"
# Out:
# oil_shock — kept: NAICS match AND present in cRet for all 3 months
#   Excluded (manual): ['PSX', 'HP']
#
# ...
#  case study of oil_shock completed: event month (2014-11)
#   c: 5-min continuous returns  |  r: 30-min full returns  |  d: daily
# ...
#
#           cBeta      cVol     cCorr     rBeta      rVol     rCorr      dVol  beta_252d  cluster_wt  nstks
# month
# t_1    1.754303  0.383588  0.535131  1.851375  0.356304  0.541918  0.465706   1.141088    0.022558     16
# t      1.982987  0.319736  0.611375  2.173040  0.309031  0.699603  0.510914   1.188763    0.020104     16
# t1     1.566749  0.416841  0.631400  1.568294  0.418488  0.674673  0.479988   1.307048    0.017416     16
# ...

# %%
df
# Out:
#     permno ticker  cBeta_t_1   cBeta_t  cBeta_t1  cVol_t_1    cVol_t  \
# 0    28484    HES   1.726786  1.896657  1.363756  0.342215  0.254427
# 1    34833    OXY   1.343939  1.413549  1.244157  0.278572  0.193544
# 2    39490    APA   1.566714  1.722077  1.325926  0.318277  0.266312
# 3    50017    RRC   1.453487  1.833286  1.301421  0.359678  0.313481
# 4    61815    NBL   1.730433  1.943138  1.436501  0.343720  0.282253
# 5    63765    SWN   1.343072  1.744278  1.476868  0.359273  0.328116
# 6    70332    APC   1.764406  1.889281  1.541039  0.377794  0.267215
# 7    75241    PXD   2.100531  1.853212  1.562750  0.451822  0.323189
# 8    75825    EOG   1.713083  1.937878  1.554808  0.376128  0.296817
# 9    76082    COG   1.650463  1.881185  1.276789  0.354425  0.293547
# 10   78877    CHK   1.983526  2.346625  1.810807  0.430716  0.378388
# 11   79915    NFX   2.236105  2.538785  2.147702  0.516505  0.403340
# 12   82196    DNR   1.829254  2.303575  1.933200  0.407086  0.457476
# ...
